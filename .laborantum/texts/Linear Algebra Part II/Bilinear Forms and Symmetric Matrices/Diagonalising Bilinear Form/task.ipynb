# %%
import numpy as np
import json_tricks

# %%
### YOUR CODE HERE ###

# %%
answer = {
    'task1': {
        'canonical': {
            'det(A - lI)': [
                [1.0, -6.0, 8.0]
            ],
            'Lambda': np.array(
                [4., 2.]
            ),
            'Q': np.array(
                [[ 0.707, -0.707],
                 [ 0.707,  0.707]]
            ),
            'C': np.array([
                [[ 0.707, -0.707],
                 [ 0.707,  0.707]]
            ]),
            'd': np.array(
                [4., 2.]
            )
        },
        'LDL': {
            'D': np.array([
                [[3., 0.],
                 [0., 2.67]]
            ]),
            'L': np.array(
                [[1., 0.],
                 [0.33, 1.]]
            ),
            'C': np.array([
                [[1., 0.],
                 [0.33, 1.]]
            ]),
            'd': np.array([
                [3., 2.67]
            ]),
            'definitiness': str('+')
        },
        'dets':{
            '1x1': [
                3
            ],
            '2x2': [
                8
            ],
            'definiteness': str('+')
        }
    },
    'task2': {
        'canonical': {
            'det(A - lI)': [
                [1.0, 15.0, 50.0]
            ],
            'Lambda': np.array(
                [-5., -10.]
            ),
            'Q': np.array(
                [[-0.89,  0.45 ],
                 [ 0.45 ,  0.89]]
            ),
            'C': np.array([
                [[-0.89,  0.45 ],
                 [ 0.45 ,  0.89]]
            ]),
            'd': np.array(
                [-5., -10.]
            )
        },
        'LDL': {
            'D': np.array([
                [[-6., 0.],
                 [0., -8.33]]
            ]),
            'L': np.array(
                [[1., 0.],
                 [0.33, 1.]]
            ),
            'C': np.array([
                [[1., 0.],
                 [0.33, 1.]]
            ]),
            'd': np.array([
                [-6., -8.33]
            ]),
            'definitiness': str('-')
        },
        'dets':{
            '1x1': [
                -6.0
            ],
            '2x2': [
                50
            ],
            'definiteness': str('+-')
        }
    },
    'task3': {
        'canonical': {
            'det(A - lI)': [
                [1.0, -6, 9, -4]
            ],
            'Lambda': np.array(
                [4., 1., 1.]
            ),
            'Q': np.array(
                [[-0.58, -0.41,  0.71],
                 [-0.58, -0.41 , -0.71],
                 [-0.58,  0.82,  0.002]]
            ),
            'C': np.array([
                [[-0.58, -0.41,  0.71],
                 [-0.58, -0.41 , -0.71],
                 [-0.58,  0.82,  0.002]]
            ]),
            'd': np.array(
                [4., 1., 1.]
            )
        },
        'LDL': {
            'D': np.array([
                [[2., 0., 0.],
                 [0., 1.5, 0.],
                 [0., 0., 1.33]]
            ]),
            'L': np.array(
                [[1., 0., 0.],
                 [0.5, 1., 0.],
                 [0.5, 0.33, 1.]]
            ),
            'C': np.array([
                [[1., 0., 0.],
                 [0.5, 1., 0.],
                 [0.5, 0.33, 1.]]
            ]),
            'd': np.array([
                [2., 1.5, 1.33]
            ]),
            'definitiness': str('+')
        },
        'dets':{
            '1x1': [
                2.0
            ],
            '2x2': [
                2.9999999999999996
            ],
            '3x3': [
                4.0
            ],
            'definiteness': str('+')
        }
    },
}


json_tricks.dump(answer, '.answer.json')
# Out:
# '{"task1": {"canonical": {"det(A - lI)": [[1.0, -6.0, 8.0]], "Lambda": {"__ndarray__": [4.0, 2.0], "dtype": "float64", "shape": [2]}, "Q": {"__ndarray__": [[0.707, -0.707], [0.707, 0.707]], "dtype": "float64", "shape": [2, 2], "Corder": true}, "C": {"__ndarray__": [[[0.707, -0.707], [0.707, 0.707]]], "dtype": "float64", "shape": [1, 2, 2], "Corder": true}, "d": {"__ndarray__": [4.0, 2.0], "dtype": "float64", "shape": [2]}}, "LDL": {"D": {"__ndarray__": [[[3.0, 0.0], [0.0, 2.67]]], "dtype": "float64", "shape": [1, 2, 2], "Corder": true}, "L": {"__ndarray__": [[1.0, 0.0], [0.33, 1.0]], "dtype": "float64", "shape": [2, 2], "Corder": true}, "C": {"__ndarray__": [[[1.0, 0.0], [0.33, 1.0]]], "dtype": "float64", "shape": [1, 2, 2], "Corder": true}, "d": {"__ndarray__": [[3.0, 2.67]], "dtype": "float64", "shape": [1, 2], "Corder": true}, "definitiness": "+"}, "dets": {"1x1": [3], "2x2": [8], "definiteness": "+"}}, "task2": {"canonical": {"det(A - lI)": [[1.0, 15.0, 50.0]], "Lambda": {"__ndar
# ...
